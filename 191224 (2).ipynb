# %% [markdown]
# <h1 style="font-size:30px; text-align:center;">
# <span style="color:red;">R</span>
# <span style="color:blue;">a</span>
# <span style="color:green;">m</span>
# <span style="color:orange;">e</span>
# <span style="color:purple;">s</span>
# <span style="color:brown;">h</span>
# <span style="color:cyan;">K</span>
# <span style="color:magenta;">u</span>
# <span style="color:lime;">m</span>
# <span style="color:pink;">a</span>
# <span style="color:teal;">r</span>
# <span style="color:gold;">P</span>
# <span style="color:deepskyblue;">r</span>
# <span style="color:crimson;">a</span>
# <span style="color:indigo;">j</span>
# <span style="color:violet;">a</span>
# <span style="color:orangered;">p</span>
# <span style="color:darkblue;">a</span>
# <span style="color:darkgreen;">t</span>
# <span style="color:chocolate;">i</span>
# </h1>

# %% [markdown]
# # 🛒 **E-commerce Data Analysis** 📊
# ### 🔍 Insights & Trends in Online Shopping

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Downloads/customer_details.csv")
df
# Out:
#    Customer ID  Age Gender Item Purchased     Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse     Clothing                   53.0
# 1            2   19   Male        Sweater     Clothing                   64.0
# 2            3   50   Male          Jeans     Clothing                    NaN
# 3            4   21   Male        Sandals     Footwear                   90.0
# 4            5   45   Male         Blouse     Clothing                   49.0
# 5            6   46   Male       Sneakers     Footwear                   20.0
# 6            7   63   Male          Shirt     Clothing                   85.0
# 7            8   27   Male         Shorts     Clothing                   34.0
# 8            9   26   Male           Coat    Outerwear                   97.0
# 9           10   57   Male        Handbag  Accessories                   31.0
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
# 5        Wyoming    M      White  Summer            2.9                 Yes
# 6        Montana    M       Gray    Fall            3.2                 Yes
# 7      Louisiana    L   Charcoal  Winter            3.2                 Yes
# 8  West Virginia    L     Silver  Summer            2.6                 Yes
# 9       Missouri    M       Pink  Spring            4.8                 Yes
#
#     Shipping Type Discount Applied Promo Code Used  Previous Purchases  \
# 0         Express              Yes             Yes                  14
# 1         Express              Yes             Yes                   2
# 2   Free Shipping              Yes             Yes                  23
# 3    Next Day Air              Yes             Yes                  49
# 4   Free Shipping              Yes             Yes                  31
# 5        Standard              Yes             Yes                  14
# 6   Free Shipping              Yes             Yes                  49
# 7   Free Shipping              Yes             Yes                  19
# 8         Express              Yes             Yes                   8
# 9  2-Day Shipping              Yes             Yes                   4
#
#   Payment Method Frequency of Purchases
# 0          Venmo            Fortnightly
# 1           Cash            Fortnightly
# 2    Credit Card                 Weekly
# 3         PayPal                 Weekly
# 4         PayPal               Annually
# 5          Venmo                 Weekly
# 6           Cash              Quarterly
# 7    Credit Card                 Weekly
# 8          Venmo               Annually
# 9           Cash              Quarterly

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                   53.0
# 1            2   19   Male        Sweater  Clothing                   64.0
# 2            3   50   Male          Jeans  Clothing                    NaN
# 3            4   21   Male        Sandals  Footwear                   90.0
# 4            5   45   Male         Blouse  Clothing                   49.0
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#    Shipping Type Discount Applied Promo Code Used  Previous Purchases  \
# 0        Express              Yes             Yes                  14
# 1        Express              Yes             Yes                   2
# 2  Free Shipping              Yes             Yes                  23
# 3   Next Day Air              Yes             Yes                  49
# 4  Free Shipping              Yes             Yes                  31
#
#   Payment Method Frequency of Purchases
# 0          Venmo            Fortnightly
# 1           Cash            Fortnightly
# 2    Credit Card                 Weekly
# 3         PayPal                 Weekly
# 4         PayPal               Annually

# %%
df.shape
# Out:
# (10, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             10 non-null     int64
#  1   Age                     10 non-null     int64
#  2   Gender                  10 non-null     object
#  3   Item Purchased          10 non-null     object
#  4   Category                10 non-null     object
#  5   Purchase Amount (USD)   9 non-null      float64
#  6   Location                10 non-null     object
#  7   Size                    10 non-null     object
#  8   Color                   10 non-null     object
#  9   Season                  10 non-null     object
#  10  Review Rating           10 non-null     float64
#  11  Subscription Status     10 non-null     object
#  12  Shipping Type           10 non-null     object
#  13  Discount Applied        10 non-null     object
#  14  Promo Code Used         10 non-null     object
#  15  Previous Purchases      10 non-null     int64
#  16  Payment Method          10 non-null     object
#  17  Frequency of Purchases  10 non-null     object
# dtypes: float64(2), int64(3), object(13)
# memory usage: 1.5+ KB

# %%
df.tail(1)
# Out:
#    Customer ID  Age Gender Item Purchased     Category  Purchase Amount (USD)  \
# 9           10   57   Male        Handbag  Accessories                   31.0
#
#    Location Size Color  Season  Review Rating Subscription Status  \
# 9  Missouri    M  Pink  Spring            4.8                 Yes
#
#     Shipping Type Discount Applied Promo Code Used  Previous Purchases  \
# 9  2-Day Shipping              Yes             Yes                   4
#
#   Payment Method Frequency of Purchases
# 9           Cash              Quarterly

# %%
#df.dropna()
df.iloc[3]
# Out:
# Customer ID                          4
# Age                                 21
# Gender                            Male
# Item Purchased                 Sandals
# Category                      Footwear
# Purchase Amount (USD)             90.0
# Location                  Rhode Island
# Size                                 M
# Color                           Maroon
# Season                          Spring
# Review Rating                      3.5
# Subscription Status                Yes
# Shipping Type             Next Day Air
# Discount Applied                   Yes
# Promo Code Used                    Yes
# Previous Purchases                  49
# Payment Method                  PayPal
# Frequency of Purchases          Weekly
# Name: 3, dtype: object

# %%
df.describe()
# Out:
#        Customer ID        Age  Purchase Amount (USD)  Review Rating  \
# count     10.00000  10.000000               9.000000      10.000000
# mean       5.50000  40.900000              58.111111       3.220000
# std        3.02765  16.203223              27.759883       0.612463
# min        1.00000  19.000000              20.000000       2.600000
# 25%        3.25000  26.250000              34.000000       2.950000
# 50%        5.50000  45.500000              53.000000       3.100000
# 75%        7.75000  53.750000              85.000000       3.200000
# max       10.00000  63.000000              97.000000       4.800000
#
#        Previous Purchases
# count            10.00000
# mean             21.30000
# std              16.97089
# min               2.00000
# 25%               9.50000
# 50%              16.50000
# 75%              29.00000
# max              49.00000

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases'],
#       dtype='object')

# %% [markdown]
# **Checking null values**

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     1
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df['Purchase Amount (USD)'] = df['Purchase Amount (USD)'].fillna(0)

# %% [markdown]
# **No any null value.**

# %%
## EDA

# %%
plt.figure(figsize=(20,7))
ax= sns.countplot(x='Age',data=df)
ax.bar_label(ax.containers[0]) 
plt.title('Age Disttribution')
plt.show()

# %% [markdown]
# **Most of the peoples are of 69 age**

# %%
ax = sns.countplot(x='Gender', data=df)
ax.bar_label(ax.containers[0])
plt.title('Gender Distribution')
plt.show()

# %% [markdown]
# **The number of males are more than the females**

# %%
#2
ax = sns.countplot(hue='Gender',x='Subscription Status', data=df)
ax.bar_label(ax.containers[0])
plt.title('Gender wise Subscription Status Distribution')
plt.show()

# %%
plt.figure(figsize=(20,5))  
ax = sns.countplot(x='Item Purchased', data=df)  
ax.bar_label(ax.containers[0])  
plt.show()

# %% [markdown]
# **Most sales are of Blouse, Pants, and Jewelry.**

# %%
plt.figure(figsize=(10,5))  
ax = sns.countplot(x='Category', data=df)  
ax.bar_label(ax.containers[0]) 
plt.show()

# %% [markdown]
# **Clothing category is most among all others.**

# %%
#2
sns.catplot(hue='Category',kind='count',x='Gender',data=df)
plt.title('Gender by Category')
plt.show()

# %%
plt.figure(figsize=(20,5))  
ax = sns.countplot(x='Location', data=df)  
plt.xticks(rotation=90)  
ax.bar_label(ax.containers[0])  
plt.show()

# %% [markdown]
# **Most buyers are from Montana, California, and Idaho.**

# %%
plt.figure(figsize=(10,5))  
ax = sns.countplot(x='Size', data=df)  
ax.bar_label(ax.containers[0]) 
plt.show()

# %% [markdown]
# **Medium size products have the highest range of sell.**

# %%
#2
sns.catplot(hue='Category',kind='count',x='Size',data=df)
plt.title('Gender by Category')
plt.show()

# %%
plt.figure(figsize=(20,5))  
ax = sns.countplot(x='Color', data=df)  
plt.xticks(rotation=90)  
ax.bar_label(ax.containers[0])  
plt.show()

# %% [markdown]
# **Buyers bought Olive, Yellow, and Silver colors most.**

# %%
plt.figure(figsize=(10,5)) 
ax = sns.countplot(x='Season', data=df)  
ax.bar_label(ax.containers[0]) 
plt.show()

# %% [markdown]
# **In Spring, Fall, Winter and then Summer seasons the sell out is most.**

# %%
plt.figure(figsize=(20,5))  
ax = sns.countplot(x='Review Rating', data=df)  
ax.bar_label(ax.containers[0])  
plt.show()

# %% [markdown]
# **The rating of 3.4, 4.0, and 4.6 were given.**

# %%
plt.figure(figsize=(5,5))  
ax = sns.countplot(x='Subscription Status', data=df)  
ax.bar_label(ax.containers[0])  
plt.show()

# %%
plt.figure(figsize=(10,5))  
ax = sns.countplot(x='Shipping Type', data=df)  
ax.bar_label(ax.containers[0])  
plt.show()

# %% [markdown]
# **Free shipping has the largest amount of buyers.**

# %%
plt.figure(figsize=(10,5)) 
ax = sns.countplot(x='Discount Applied', data=df) 
ax.bar_label(ax.containers[0]) 
plt.show()

# %%
plt.figure(figsize=(10,5)) 
ax = sns.countplot(x='Promo Code Used', data=df) 
ax.bar_label(ax.containers[0])  
plt.show()

# %% [markdown]
# **2223 buyers have not used Promo Code.**

# %%
plt.figure(figsize=(15,5))  
ax = sns.countplot(x='Previous Purchases', data=df)  
ax.bar_label(ax.containers[0])  
plt.show()

# %% [markdown]
# **97 buyers have 31 previous purchases.**

# %%
plt.figure(figsize=(15,5))  
ax = sns.countplot(x='Payment Method', data=df)  
ax.bar_label(ax.containers[0])  
plt.show()

# %% [markdown]
# **677 buyers used PayPal, 671 used Credit Card, and 670 paid Cash.**

# %%
plt.figure(figsize=(15,5))  
ax = sns.countplot(x='Frequency of Purchases', data=df)  
ax.bar_label(ax.containers[0])  
plt.show()

# %%
sales = df.groupby('Gender')['Purchase Amount (USD)'].sum().reset_index().sort_values(by='Purchase Amount (USD)', ascending=False)
sns.barplot(data=sales, x='Gender', y='Purchase Amount (USD)')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             10 non-null     int64
#  1   Age                     10 non-null     int64
#  2   Gender                  10 non-null     object
#  3   Item Purchased          10 non-null     object
#  4   Category                10 non-null     object
#  5   Purchase Amount (USD)   10 non-null     float64
#  6   Location                10 non-null     object
#  7   Size                    10 non-null     object
#  8   Color                   10 non-null     object
#  9   Season                  10 non-null     object
#  10  Review Rating           10 non-null     float64
#  11  Subscription Status     10 non-null     object
#  12  Shipping Type           10 non-null     object
#  13  Discount Applied        10 non-null     object
#  14  Promo Code Used         10 non-null     object
#  15  Previous Purchases      10 non-null     int64
#  16  Payment Method          10 non-null     object
#  17  Frequency of Purchases  10 non-null     object
# dtypes: float64(2), int64(3), object(13)
# memory usage: 1.5+ KB

# %%
plt.figure(figsize=(20,5))
sales = df.groupby(['Item Purchased'],as_index=False)['Purchase Amount (USD)'].sum().sort_values(by='Purchase Amount (USD)',ascending=False)
sns.barplot(data=sales,x='Item Purchased',y='Purchase Amount (USD)')
plt.show()

# %%
plt.figure(figsize=(10,5))
sales = df.groupby(['Category'],as_index=False)['Purchase Amount (USD)'].sum().sort_values(by='Purchase Amount (USD)',ascending=False)
sns.barplot(data=sales,x='Category',y='Purchase Amount (USD)')
plt.show()

# %% [markdown]
# **Clothing category has the most Purchased amount.**

# %%
plt.figure(figsize=(20,5))
sales = df.groupby(['Location'],as_index=False)['Purchase Amount (USD)'].sum().sort_values(by='Purchase Amount (USD)',ascending=False)
sns.barplot(data=sales,x='Location',y='Purchase Amount (USD)')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Montana has peoduced the most amount.**

# %%
plt.figure(figsize=(10,5))
sales = df.groupby(['Size'],as_index=False)['Purchase Amount (USD)'].sum().sort_values(by='Purchase Amount (USD)',ascending=False)
sns.barplot(data=sales,x='Size',y='Purchase Amount (USD)')
plt.show()

# %% [markdown]
# **Medium size has generated the most profit.**

# %%
plt.figure(figsize=(10,5))
sales = df.groupby(['Color'],as_index=False)['Purchase Amount (USD)'].sum().sort_values(by='Purchase Amount (USD)',ascending=False)
sns.barplot(data=sales,x='Color',y='Purchase Amount (USD)')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Buyers bought products of green color.**

# %%
plt.figure(figsize=(10,5))
sales = df.groupby(['Season'],as_index=False)['Purchase Amount (USD)'].sum().sort_values(by='Purchase Amount (USD)',ascending=False)
sns.barplot(data=sales,x='Season',y='Purchase Amount (USD)')
plt.show()

# %% [markdown]
# **Fall season has produced the most profit.**

# %%
plt.figure(figsize=(5,5))
sales = df.groupby(['Subscription Status'],as_index=False)['Purchase Amount (USD)'].sum().sort_values(by='Purchase Amount (USD)',ascending=False)
sns.barplot(data=sales,x='Subscription Status',y='Purchase Amount (USD)')
plt.show()

# %%
# Most Profit came from those who haven't subscribed.

# %%
plt.figure(figsize=(15,5))
sales = df.groupby(['Shipping Type'],as_index=False)['Purchase Amount (USD)'].sum().sort_values(by='Purchase Amount (USD)',ascending=False)
sns.barplot(data=sales,x='Shipping Type',y='Purchase Amount (USD)')
plt.show()

# %% [markdown]
# **Free shipping producd most profit.**

# %%
plt.figure(figsize=(10,5))
sales = df.groupby(['Discount Applied'],as_index=False)['Purchase Amount (USD)'].sum().sort_values(by='Purchase Amount (USD)',ascending=False)
sns.barplot(data=sales,x='Discount Applied',y='Purchase Amount (USD)')
plt.show()

# %%
plt.figure(figsize=(10,5))
sales = df.groupby(['Promo Code Used'],as_index=False)['Purchase Amount (USD)'].sum().sort_values(by='Purchase Amount (USD)',ascending=False)
sns.barplot(data=sales,x='Promo Code Used',y='Purchase Amount (USD)')
plt.show()

# %% [markdown]
# **Most of the profit came from those who hadn't used Promo Code.**

# %%
plt.figure(figsize=(10,5))
sales = df.groupby(['Payment Method'],as_index=False)['Purchase Amount (USD)'].sum().sort_values(by='Purchase Amount (USD)',ascending=False)
sns.barplot(data=sales,x='Payment Method',y='Purchase Amount (USD)')
plt.show()

# %% [markdown]
# **Most amount was created by Credit card, and then PayPal.**

# %%
plt.figure(figsize=(10,5))
sales = df.groupby(['Frequency of Purchases'],as_index=False)['Purchase Amount (USD)'].sum().sort_values(by='Purchase Amount (USD)',ascending=False)
sns.barplot(data=sales,x='Frequency of Purchases',y='Purchase Amount (USD)')
plt.show()

# %%
sales = df.groupby(['Gender'],as_index=False)['Review Rating'].sum().sort_values(by='Review Rating',ascending=False)
sns.barplot(data=sales,x='Gender',y='Review Rating')
plt.show()

# %% [markdown]
# **Males have given the most Review Rating.**

# %%
plt.figure(figsize=(20,5))
sales = df.groupby(['Item Purchased'],as_index=False)['Review Rating'].sum().sort_values(by='Review Rating',ascending=False)
sns.barplot(data=sales,x='Item Purchased',y='Review Rating')
plt.show()

# %% [markdown]
# **Jewelery buyers have given the a lot of reviews.**

# %%
plt.figure(figsize=(10,5))
sales = df.groupby(['Category'],as_index=False)['Review Rating'].sum().sort_values(by='Review Rating',ascending=False)
sns.barplot(data=sales,x='Category',y='Review Rating')
plt.show()

# %% [markdown]
# **Clothing buyers have given the most reviews.**

# %%
plt.figure(figsize=(20,5))
sales = df.groupby(['Location'],as_index=False)['Review Rating'].sum().sort_values(by='Review Rating',ascending=False)
sns.barplot(data=sales,x='Location',y='Review Rating')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Mantola's buyers have given most reviews.**

# %%
plt.figure(figsize=(10,5))
sales = df.groupby(['Size'],as_index=False)['Review Rating'].sum().sort_values(by='Review Rating',ascending=False)
sns.barplot(data=sales,x='Size',y='Review Rating')
plt.show()

# %% [markdown]
# **Medium size buyers have given most reviews.**

# %%
plt.figure(figsize=(10,5))
sales = df.groupby(['Color'],as_index=False)['Review Rating'].sum().sort_values(by='Review Rating',ascending=False)
sns.barplot(data=sales,x='Color',y='Review Rating')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Yellow color buyers have given most reviews.**

# %%
plt.figure(figsize=(10,5))
sales = df.groupby(['Season'],as_index=False)['Review Rating'].sum().sort_values(by='Review Rating',ascending=False)
sns.barplot(data=sales,x='Season',y='Review Rating')
plt.show()

# %%
plt.figure(figsize=(5,5))
sales = df.groupby(['Subscription Status'],as_index=False)['Review Rating'].sum().sort_values(by='Review Rating',ascending=False)
sns.barplot(data=sales,x='Subscription Status',y='Review Rating')
plt.show()

# %%
plt.figure(figsize=(15,5))
sales = df.groupby(['Shipping Type'],as_index=False)['Review Rating'].sum().sort_values(by='Review Rating',ascending=False)
sns.barplot(data=sales,x='Shipping Type',y='Review Rating')
plt.show()

# %% [markdown]
# **Free shipping buyers have given the most reviews.**

# %%
plt.figure(figsize=(10,5))
sales = df.groupby(['Discount Applied'],as_index=False)['Review Rating'].sum().sort_values(by='Review Rating',ascending=False)
sns.barplot(data=sales,x='Discount Applied',y='Review Rating')
plt.show()

# %%
plt.figure(figsize=(10,5))
sales = df.groupby(['Promo Code Used'],as_index=False)['Review Rating'].sum().sort_values(by='Review Rating',ascending=False)
sns.barplot(data=sales,x='Promo Code Used',y='Review Rating')
plt.show()

# %%
plt.figure(figsize=(10,5))
sales = df.groupby(['Payment Method'],as_index=False)['Review Rating'].sum().sort_values(by='Review Rating',ascending=False)
sns.barplot(data=sales,x='Payment Method',y='Review Rating')
plt.show()

# %% [markdown]
# **PayPal users have given the most reviews.**

# %%
plt.figure(figsize=(10,5))
sales = df.groupby(['Frequency of Purchases'],as_index=False)['Review Rating'].sum().sort_values(by='Review Rating',ascending=False)
sns.barplot(data=sales,x='Frequency of Purchases',y='Review Rating')
plt.show()

# %%
sales = df.groupby('Frequency of Purchases')['Review Rating'].sum().sort_values(ascending=False)
sales.plot(kind='bar', color='blue', figsize=(10, 5))
plt.title('Total Review Rating by Frequency of Purchases')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ***=====================================================================================================================***

# %% [markdown]
# <div style="text-align: center; font-size: 30px; font-weight: bold;">
#     Thank You
# </div>
